# %%
from keras.datasets import reuters
from keras import layers, models, optimizers, losses
import matplotlib.pyplot as plt
import numpy as np

# %%
def vectorize_sequences(sequences, dimension=10_000):
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        results[i, sequence] = 1.
    return results

# %%
(train_data, train_labels), (test_data, test_labels) = reuters.load_data(num_words=10000)
print(len(train_data), len(test_data))
print(train_data[10])

train_data, test_data = vectorize_sequences(train_data), vectorize_sequences(test_data)
# print(train_data[10])
# Out:
# 8982 2246
# [1, 245, 273, 207, 156, 53, 74, 160, 26, 14, 46, 296, 26, 39, 74, 2979, 3554, 14, 46, 4689, 4329, 86, 61, 3499, 4795, 14, 61, 451, 4329, 17, 12]

# %%
word_index = reuters.get_word_index()
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])
decoded_newswire = ' '.join([reverse_word_index.get(i - 3, '?') for i in train_data[0]])
# print(word_index)

# %%
model = models.Sequential([
    layers.Dense(96, activation='elu', input_shape=(10_000,)),
    layers.Dense(64, activation='elu'),
    layers.Dense(46, activation='softmax')])

model.compile(optimizer=optimizers.RMSprop(),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 96)                960096
#
#  dense_1 (Dense)             (None, 64)                6208
#
#  dense_2 (Dense)             (None, 46)                2990
#
# =================================================================
# Total params: 969,294
# Trainable params: 969,294
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = model.fit(epochs=25, batch_size=512, x=train_data, y=train_labels,
                 validation_data=(test_data, test_labels))
# Out:
# Epoch 1/25
# 18/18 [==============================] - 3s 25ms/step - loss: 1.9989 - accuracy: 0.5902 - val_loss: 1.3720 - val_accuracy: 0.6866
# Epoch 2/25
# 18/18 [==============================] - 0s 13ms/step - loss: 1.0467 - accuracy: 0.7762 - val_loss: 1.1069 - val_accuracy: 0.7636
# Epoch 3/25
# 18/18 [==============================] - 0s 13ms/step - loss: 0.7317 - accuracy: 0.8508 - val_loss: 0.9770 - val_accuracy: 0.7885
# Epoch 4/25
# 18/18 [==============================] - 0s 13ms/step - loss: 0.5291 - accuracy: 0.8946 - val_loss: 0.9167 - val_accuracy: 0.8014
# Epoch 5/25
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3859 - accuracy: 0.9202 - val_loss: 0.9060 - val_accuracy: 0.8005
# Epoch 6/25
# 18/18 [==============================] - 0s 12ms/step - loss: 0.2995 - accuracy: 0.9365 - val_loss: 0.9307 - val_accuracy: 0.7961
# Epoch 7/25
# 18/18 [==============================] - 0s 12ms/step - loss: 0.2395 - accuracy: 0.9449 - val_loss: 0.9485 - val_accuracy: 0.8001
# Epoch 8/25
# 18/18 [==============================] - 0s 12ms/step - loss: 0.2032 - accuracy: 0.9478 - val_loss: 0.9609 - val_accuracy: 0.7992
# Epoch 9/25
# 18/18 [==============================] - 0s 12ms/step - loss: 0.1819 - accuracy: 0.9513 - val_loss: 1.0043 - val_accuracy: 0.7965
# Epoch 10/25
# 18/18 [==============================] - 0s 12ms/step - loss: 0.1524 - accuracy: 0.9538 - val_loss: 1.0278 - val_accuracy: 0.7952
# Epoch 11/25
# 18/18 [==============================] - 0s 12ms/step - loss: 0.1485 - accuracy: 0.9520 - val_loss: 1.0398 - val_accuracy: 0.7983
# Epoch 12/25
# 18/18 [==============================] - 0s 12ms/step - loss: 0.1384 - accuracy: 0.9536 - val_loss: 1.0839 - val_accuracy: 0.7947
# Epoch 13/25
# 18/18 [==============================] - 0s 12ms/step - loss: 0.1318 - accuracy: 0.9529 - val_loss: 1.0871 - val_accuracy: 0.7956
# Epoch 14/25
# 18/18 [==============================] - 0s 12ms/step - loss: 0.1253 - accuracy: 0.9525 - val_loss: 1.1446 - val_accuracy: 0.7850
# Epoch 15/25
# 18/18 [==============================] - 0s 12ms/step - loss: 0.1227 - accuracy: 0.9525 - val_loss: 1.1445 - val_accuracy: 0.7876
# Epoch 16/25
# 18/18 [==============================] - 0s 12ms/step - loss: 0.1207 - accuracy: 0.9521 - val_loss: 1.1519 - val_accuracy: 0.7907
# Epoch 17/25
# 18/18 [==============================] - 0s 13ms/step - loss: 0.1150 - accuracy: 0.9526 - val_loss: 1.1960 - val_accuracy: 0.7925
# Epoch 18/25
# 18/18 [==============================] - 0s 13ms/step - loss: 0.1120 - accuracy: 0.9537 - val_loss: 1.2285 - val_accuracy: 0.7774
# Epoch 19/25
# 18/18 [==============================] - 0s 13ms/step - loss: 0.1090 - accuracy: 0.9537 - val_loss: 1.1690 - val_accuracy: 0.7912
# Epoch 20/25
# 18/18 [==============================] - 0s 12ms/step - loss: 0.1045 - accuracy: 0.9535 - val_loss: 1.1828 - val_accuracy: 0.7894
# Epoch 21/25
# 18/18 [==============================] - 0s 12ms/step - loss: 0.1046 - accuracy: 0.9544 - val_loss: 1.2321 - val_accuracy: 0.7836
# Epoch 22/25
# 18/18 [==============================] - 0s 12ms/step - loss: 0.1020 - accuracy: 0.9536 - val_loss: 1.2275 - val_accuracy: 0.7863
# Epoch 23/25
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0983 - accuracy: 0.9554 - val_loss: 1.2704 - val_accuracy: 0.7769
# Epoch 24/25
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0989 - accuracy: 0.9537 - val_loss: 1.2098 - val_accuracy: 0.7930
# Epoch 25/25
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0966 - accuracy: 0.9522 - val_loss: 1.2146 - val_accuracy: 0.7943

# %%
loss = hist.history['loss']
val_loss = hist.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.clf()
acc = hist.history['acc']
val_acc = hist.history['val_accuracy']
plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
hist.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
